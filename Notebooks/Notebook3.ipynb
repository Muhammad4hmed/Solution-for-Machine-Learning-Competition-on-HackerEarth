# %%
# !pip install pycaret

# %%
import pandas as pd
import numpy as np
from pycaret.regression import *

# %%
train = pd.read_csv('/kaggle/input/he-mlcomp/Train.csv')
test = pd.read_csv('/kaggle/input/he-mlcomp/Test.csv')

# %%
exp_reg = setup(train, target = 'Attrition_rate', train_size = 0.6, transform_target = True,
               remove_outliers = True, feature_interaction = True)

# %%
tunned_lasso = tune_model('br',ensemble = True, method = 'Bagging')

# %%
lr_predictions_holdout = predict_model(tunned_lasso,data=test)

# %%
lr_predictions_holdout['Label'].
